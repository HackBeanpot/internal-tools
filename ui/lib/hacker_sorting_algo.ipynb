# %%
import pandas as pd

hacker_values = pd.read_csv("post_acceptance.csv")

#print(hacker_values)
# hacker_values = hacker_values.loc[:,'hangingWithFriends': 'duringClass']
# hacker_values = 
hacker_values
# Out:
#                                    email  isAdmin applicationStatus  \
# 0           ostapenko.d@northeastern.edu      NaN         Submitted
# 1   aristizabalnorena.k@northeastern.edu      NaN         Submitted
# 2             cheung.ra@northeastern.edu      NaN         Submitted
# 3               shreypatel2224@gmail.com      NaN         Submitted
# 4                   ericsun828@gmail.com      NaN         Submitted
# 5                           ankit@bu.edu      NaN         Submitted
# 6              keshri.r@northeastern.edu      NaN         Submitted
# 7              chan.gar@northeastern.edu      NaN         Submitted
# 8               devashishsood9@gmail.com      NaN         Submitted
# 9              iyer.raj@northeastern.edu      NaN         Submitted
# 10               tristen.jd.li@gmail.com      NaN         Submitted
# 11              shreya.21reddy@gmail.com      NaN         Submitted
# 12           tripakis.m@northeastern.edu      NaN         Submitted
# ...

# %%
tatooine = [0] * 20
essos = [0] * 20
si_wong = [0] * 20
arrakis = [0] * 20
biome = [0] * 20

for x in range(len(hacker_values.hangingWithFriends)):
    if "Listening" in hacker_values.hangingWithFriends[x]:
        tatooine[x] += 1
    if "Talking" in hacker_values.hangingWithFriends[x]:
        arrakis[x] += 1
    if "Leading" in hacker_values.hangingWithFriends[x]:
        essos[x] += 1
    if "On a discord channel" in hacker_values.hangingWithFriends[x]:
        biome[x] += 1
    if "Thinking" in hacker_values.hangingWithFriends[x]:
        si_wong[x] += 1
        
for x in range(len(hacker_values.zombieApocalypse)):
    if "Water purifying" in hacker_values.zombieApocalypse[x]:
        tatooine[x] += 1
    if "GoPro" in hacker_values.zombieApocalypse[x]:
        arrakis[x] += 1
    if "emergency" in hacker_values.zombieApocalypse[x]:
        essos[x] += 1
    if "Laptop" in hacker_values.zombieApocalypse[x]:
        biome[x] += 1
    if "Survival for" in hacker_values.zombieApocalypse[x]:
        si_wong[x] += 1
        
for x in range(len(hacker_values.takeOverNation)):
    if "Use the strength" in hacker_values.zombieApocalypse[x]:
        tatooine[x] += 1
    if "Stage" in hacker_values.zombieApocalypse[x]:
        arrakis[x] += 1
    if "Send" in hacker_values.zombieApocalypse[x]:
        essos[x] += 1
    if "Laptop" in hacker_values.zombieApocalypse[x]:
        biome[x] += 1
    if "weakness" in hacker_values.zombieApocalypse[x]:
        si_wong[x] += 1
        
for x in range(len(hacker_values.aspirations)):
    if "Be well" in hacker_values.aspirations[x]:
        tatooine[x] += 1
    if "Be a risk" in hacker_values.aspirations[x]:
        arrakis[x] += 1
    if "Be a ruler" in hacker_values.aspirations[x]:
        essos[x] += 1
    if "Be remembered" in hacker_values.aspirations[x]:
        biome[x] += 1
    if "Be wise" in hacker_values.aspirations[x]:
        si_wong[x] += 1
        
        
for x in range(len(hacker_values.study)):
    if "upperlcassmen" in hacker_values.study[x]:
        tatooine[x] += 1
    if "Trick" in hacker_values.study[x]:
        arrakis[x] += 1
    if "Start" in hacker_values.study[x]:
        essos[x] += 1
    if "Go to online" in hacker_values.study[x]:
        biome[x] += 1
    if "Drill pass" in hacker_values.study[x]:
        si_wong[x] += 1
        
for x in range(len(hacker_values.stuckInElevator)):
    if "Find your RA" in hacker_values.stuckInElevator[x]:
        tatooine[x] += 1
    if "Try to kick" in hacker_values.stuckInElevator[x]:
        arrakis[x] += 1
    if "First tell all" in hacker_values.stuckInElevator[x]:
        essos[x] += 1
    if "Pretend" in hacker_values.stuckInElevator[x]:
        biome[x] += 1
    if "Try to debug" in hacker_values.stuckInElevator[x]:
        si_wong[x] += 1
        
for x in range(len(hacker_values.socialMedia)):
    if "I don't have" in hacker_values.socialMedia[x]:
        tatooine[x] += 1
    if "TikTok" in hacker_values.socialMedia[x]:
        arrakis[x] += 1
    if "Instagram" in hacker_values.socialMedia[x]:
        essos[x] += 1
    if "Twitch" in hacker_values.socialMedia[x]:
        biome[x] += 1
    if "Pinterest" in hacker_values.socialMedia[x]:
        si_wong[x] += 1
        
for x in range(len(hacker_values.duringClass)):
    if "Do other" in hacker_values.socialMedia[x]:
        tatooine[x] += 1
    if "Haha" in hacker_values.socialMedia[x]:
        arrakis[x] += 1
    if "questions" in hacker_values.socialMedia[x]:
        essos[x] += 1
    if "mechanical keyboard" in hacker_values.socialMedia[x]:
        biome[x] += 1
    if "listening and reflecting" in hacker_values.socialMedia[x]:
        si_wong[x] += 1
        

hacker_values["tatooine"] = pd.to_numeric(tatooine)
hacker_values["arrakis"] = pd.to_numeric(arrakis)
hacker_values["essos"] = pd.to_numeric(essos)
hacker_values["biome"] = pd.to_numeric(biome)
hacker_values["si_wong"] = pd.to_numeric(si_wong)

new_hacker_val = hacker_values.iloc[:,-5:]
hacker_values["max_cabin"] = new_hacker_val.idxmax(axis=1)
# hacker_values
hacker_values
# Out:
#                                    email  isAdmin applicationStatus  \
# 0           ostapenko.d@northeastern.edu      NaN         Submitted
# 1   aristizabalnorena.k@northeastern.edu      NaN         Submitted
# 2             cheung.ra@northeastern.edu      NaN         Submitted
# 3               shreypatel2224@gmail.com      NaN         Submitted
# 4                   ericsun828@gmail.com      NaN         Submitted
# 5                           ankit@bu.edu      NaN         Submitted
# 6              keshri.r@northeastern.edu      NaN         Submitted
# 7              chan.gar@northeastern.edu      NaN         Submitted
# 8               devashishsood9@gmail.com      NaN         Submitted
# 9              iyer.raj@northeastern.edu      NaN         Submitted
# 10               tristen.jd.li@gmail.com      NaN         Submitted
# 11              shreya.21reddy@gmail.com      NaN         Submitted
# 12           tripakis.m@northeastern.edu      NaN         Submitted
# ...

# %%
hacker_values.to_csv("final_hacker_list_updated.csv")
